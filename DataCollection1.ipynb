# %%
import pandas as pd
import json

# Function to collect data
def collect_translation_data():
    data = []
    print("Enter 'STOP' to end data collection.")
    
    while True:
        kikuyu = input("Enter Kikuyu word/phrase (or 'STOP' to finish): ")
        if kikuyu.lower() == 'stop':
            break
        swahili = input("Enter corresponding Swahili translation: ")
        english = input("Enter corresponding English translation: ")
        
        # Append the collected data as a dictionary
        data.append({
            "Kikuyu": kikuyu,
            "Swahili": swahili,
            "English": english
        })
    
    return data

# Function to save data to CSV
def save_data_to_csv(data, filename='translations.csv'):
    df = pd.DataFrame(data)
    df.to_csv(filename, index=False, encoding='utf-8')
    print(f"Data saved to {filename}")

# Function to save data to JSON
def save_data_to_json(data, filename='translations.json'):
    with open(filename, 'w', encoding='utf-8') as json_file:
        json.dump(data, json_file, ensure_ascii=False, indent=4)
    print(f"Data saved to {filename}")

# Main program execution
if __name__ == "__main__":
    collected_data = collect_translation_data()
    if collected_data:
        save_format = input("Enter preferred save format (CSV/JSON): ").lower()
        if save_format == 'csv':
            save_data_to_csv(collected_data)
        elif save_format == 'json':
            save_data_to_json(collected_data)
        else:
            print("Invalid format. Data will not be saved.")
    else:
        print("No data collected.")
# Out:
# Enter 'STOP' to end data collection.
# Enter Kikuyu word/phrase (or 'STOP' to finish):  baba
# Enter corresponding Swahili translation:  baba
# Enter corresponding English translation:  father
# Enter Kikuyu word/phrase (or 'STOP' to finish):  Mami / Maitũ
# Enter corresponding Swahili translation:  mama
# Enter corresponding English translation:  mother
# Enter Kikuyu word/phrase (or 'STOP' to finish):  mũriũ
# Enter corresponding Swahili translation:  mwana
# Enter corresponding English translation:  son
# Enter Kikuyu word/phrase (or 'STOP' to finish):  mwarĩ
# Enter corresponding Swahili translation:  binti
# Enter corresponding English translation:  daughter
# Enter Kikuyu word/phrase (or 'STOP' to finish):  mwarĩ wa nyina
# Enter corresponding Swahili translation:  dada
# Enter corresponding English translation:  sister
# Enter Kikuyu word/phrase (or 'STOP' to finish):  mũrũ wa nyina
# Enter corresponding Swahili translation:  kaka
# Enter corresponding English translation:  brother
# Enter Kikuyu word/phrase (or 'STOP' to finish):  guka
# Enter corresponding Swahili translation:  babu
# Enter corresponding English translation:  grand father
# Enter Kikuyu word/phrase (or 'STOP' to finish):  cũcũ
# Enter corresponding Swahili translation:  mama mkubwa
# Enter corresponding English translation:  grand mother
# Enter Kikuyu word/phrase (or 'STOP' to finish):  mama
# Enter corresponding Swahili translation:  mjomba
# Enter corresponding English translation:  uncle
# Enter Kikuyu word/phrase (or 'STOP' to finish):  tata
# Enter corresponding Swahili translation:  shangazi
# Enter corresponding English translation:  aunt
# Enter Kikuyu word/phrase (or 'STOP' to finish):  mũrũ wa tata
# Enter corresponding Swahili translation:  binamu
# Enter corresponding English translation:  male cousin
# Enter Kikuyu word/phrase (or 'STOP' to finish):  mwarĩ wa tata
# Enter corresponding Swahili translation:  binamu wa kike
# Enter corresponding English translation:  female cousin
# Enter Kikuyu word/phrase (or 'STOP' to finish):  mũihwa
# Enter corresponding Swahili translation:  mpwa
# Enter corresponding English translation:  nephew
# Enter Kikuyu word/phrase (or 'STOP' to finish):  mũihwa
# Enter corresponding Swahili translation:  mpwa wa kiume
# Enter corresponding English translation:  nephew
# Enter Kikuyu word/phrase (or 'STOP' to finish):  mũihwa
# Enter corresponding Swahili translation:  mpwa wa kike
# Enter corresponding English translation:  niece
# Enter Kikuyu word/phrase (or 'STOP' to finish):  mũihwa
# Enter corresponding Swahili translation:  mpwa
# Enter corresponding English translation:  niece
# Enter Kikuyu word/phrase (or 'STOP' to finish):  stop
# Enter preferred save format (CSV/JSON):  JSON
# Data saved to translations.json

# %%
import pandas as pd
import json

# Function to collect data
def collect_translation_data():
    data = []
    print("Enter 'STOP' to end data collection.")
    
    while True:
        kikuyu = input("Enter Kikuyu word/phrase (or 'STOP' to finish): ")
        if kikuyu.lower() == 'stop':
            break
        swahili = input("Enter corresponding Swahili translation: ")
        english = input("Enter corresponding English translation: ")
        
        # Append the collected data as a dictionary
        data.append({
            "Kikuyu": kikuyu,
            "Swahili": swahili,
            "English": english
        })
    
    return data

# Function to save data to CSV
def save_data_to_csv(data, filename='translations.csv'):
    df = pd.DataFrame(data)
    df.to_csv(filename, index=False, encoding='utf-8')
    print(f"Data saved to {filename}")

# Function to save data to JSON
def save_data_to_json(data, filename='translations.json'):
    with open(filename, 'w', encoding='utf-8') as json_file:
        json.dump(data, json_file, ensure_ascii=False, indent=4)
    print(f"Data saved to {filename}")

# Main program execution
if __name__ == "__main__":
    collected_data = collect_translation_data()
    if collected_data:
        save_format = input("Enter preferred save format (CSV/JSON): ").lower()
        if save_format == 'csv':
            save_data_to_csv(collected_data)
        elif save_format == 'json':
            save_data_to_json(collected_data)
        else:
            print("Invalid format. Data will not be saved.")
    else:
        print("No data collected.")
# Out:
# Enter 'STOP' to end data collection.
# Enter Kikuyu word/phrase (or 'STOP' to finish):  Mũrũthi
# Enter corresponding Swahili translation:  simba
# Enter corresponding English translation:  lion
# Enter Kikuyu word/phrase (or 'STOP' to finish):  hiti
# Enter corresponding Swahili translation:  fisi
# Enter corresponding English translation:  hyena
# Enter Kikuyu word/phrase (or 'STOP' to finish):  Njogu
# Enter corresponding Swahili translation:  ndovu
# Enter corresponding English translation:  elephant
# Enter Kikuyu word/phrase (or 'STOP' to finish):  Munyi
# Enter corresponding Swahili translation:  Kifaru
# Enter corresponding English translation:  Rhino
# Enter Kikuyu word/phrase (or 'STOP' to finish):  Nguũ
# Enter corresponding Swahili translation:  kiboko
# Enter corresponding English translation:  hippo
# Enter Kikuyu word/phrase (or 'STOP' to finish):  Mũitĩrĩro
# Enter corresponding Swahili translation:  twiga
# Enter corresponding English translation:  Giraffe
# Enter Kikuyu word/phrase (or 'STOP' to finish):  Nyau
# Enter corresponding Swahili translation:  paka
# Enter corresponding English translation:  cat
# Enter Kikuyu word/phrase (or 'STOP' to finish):  Ngui
# Enter corresponding Swahili translation:  umbwa
# Enter corresponding English translation:  dog
# Enter Kikuyu word/phrase (or 'STOP' to finish):  Ngũkũ
# Enter corresponding Swahili translation:  kuku
# Enter corresponding English translation:  Chicken
# Enter Kikuyu word/phrase (or 'STOP' to finish):  Mbũri
# Enter corresponding Swahili translation:  mbuzi
# Enter corresponding English translation:  goat
# Enter Kikuyu word/phrase (or 'STOP' to finish):  Ng'ombe
# Enter corresponding Swahili translation:  Ng'ombe
# Enter corresponding English translation:  cow
# Enter Kikuyu word/phrase (or 'STOP' to finish):  Ngo'ndu
# Enter corresponding Swahili translation:  kondoo
# Enter corresponding English translation:  sheep
# Enter Kikuyu word/phrase (or 'STOP' to finish):  Mbũkũ
# Enter corresponding Swahili translation:  sungura
# Enter corresponding English translation:  rabbit
# Enter Kikuyu word/phrase (or 'STOP' to finish):  Ngamĩra
# Enter corresponding Swahili translation:  Ngamia
# Enter corresponding English translation:  camel
# Enter Kikuyu word/phrase (or 'STOP' to finish):  Ndutura
# Enter corresponding Swahili translation:   Njiwa
# Enter corresponding English translation:  dove
# Enter Kikuyu word/phrase (or 'STOP' to finish):  Bata
# Enter corresponding Swahili translation:  Bata
# Enter corresponding English translation:  Duck

# %%
import pandas as pd
import json

# Function to collect data
def collect_translation_data():
    data = []
    print("Enter 'STOP' to end data collection.")
    
    while True:
        kikuyu = input("Enter Kikuyu word/phrase (or 'STOP' to finish): ")
        if kikuyu.lower() == 'stop':
            break
        swahili = input("Enter corresponding Swahili translation: ")
        english = input("Enter corresponding English translation: ")
        
        # Append the collected data as a dictionary
        data.append({
            "Kikuyu": kikuyu,
            "Swahili": swahili,
            "English": english
        })
    
    return data

# Function to save data to CSV
def save_data_to_csv(data, filename='translations.csv'):
    df = pd.DataFrame(data)
    df.to_csv(filename, index=False, encoding='utf-8')
    print(f"Data saved to {filename}")

# Function to save data to JSON
def save_data_to_json(data, filename='translations.json'):
    with open(filename, 'w', encoding='utf-8') as json_file:
        json.dump(data, json_file, ensure_ascii=False, indent=4)
    print(f"Data saved to {filename}")

# Main program execution
if __name__ == "__main__":
    collected_data = collect_translation_data()
    if collected_data:
        save_format = input("Enter preferred save format (CSV/JSON): ").lower()
        if save_format == 'csv':
            save_data_to_csv(collected_data)
        elif save_format == 'json':
            save_data_to_json(collected_data)
        else:
            print("Invalid format. Data will not be saved.")
    else:
        print("No data collected.")
# Out:
# Enter 'STOP' to end data collection.
# Enter Kikuyu word/phrase (or 'STOP' to finish):  Mũrũthi
# Enter corresponding Swahili translation:  Simba
# Enter corresponding English translation:  Lion
# Enter Kikuyu word/phrase (or 'STOP' to finish):  Hiti
# Enter corresponding Swahili translation:  Fisi
# Enter corresponding English translation:  Hyena
# Enter Kikuyu word/phrase (or 'STOP' to finish):  Njogu
# Enter corresponding Swahili translation:  Tembo
# Enter corresponding English translation:  Elephant
# Enter Kikuyu word/phrase (or 'STOP' to finish):  Munyi
# Enter corresponding Swahili translation:  Kifaru
# Enter corresponding English translation:  Rhino
# Enter Kikuyu word/phrase (or 'STOP' to finish):  Nguũ
# Enter corresponding Swahili translation:  Kiboko
# Enter corresponding English translation:  Hippo
# Enter Kikuyu word/phrase (or 'STOP' to finish):  Mũitĩrĩro
# Enter corresponding Swahili translation:  Twiga
# Enter corresponding English translation:  Giraffe
# Enter Kikuyu word/phrase (or 'STOP' to finish):  Nyau
# Enter corresponding Swahili translation:  Paka
# Enter corresponding English translation:  Cat
# Enter Kikuyu word/phrase (or 'STOP' to finish):  Ngui
# Enter corresponding Swahili translation:  Mbwa
# Enter corresponding English translation:  Dog
# Enter Kikuyu word/phrase (or 'STOP' to finish):  Mbũri
# Enter corresponding Swahili translation:  Mbuzi
# Enter corresponding English translation:  Goat
# Enter Kikuyu word/phrase (or 'STOP' to finish):  Ng'ombe
# Enter corresponding Swahili translation:  Ng'ombe
# Enter corresponding English translation:  Cow
# Enter Kikuyu word/phrase (or 'STOP' to finish):  Ngũkũ
# Enter corresponding Swahili translation:  Kuku
# Enter corresponding English translation:  Chicken
# Enter Kikuyu word/phrase (or 'STOP' to finish):  Ngo'ndu
# Enter corresponding Swahili translation:  Kondoo
# Enter corresponding English translation:  Sheep
# Enter Kikuyu word/phrase (or 'STOP' to finish):  Mbũkũ
# Enter corresponding Swahili translation:  Sungura
# Enter corresponding English translation:  Rabbit
# Enter Kikuyu word/phrase (or 'STOP' to finish):  Ngamĩra
# Enter corresponding Swahili translation:  Ngamia
# Enter corresponding English translation:  Camel
# Enter Kikuyu word/phrase (or 'STOP' to finish):  Ndutura
# Enter corresponding Swahili translation:  Njiwa
# Enter corresponding English translation:  Dove
# Enter Kikuyu word/phrase (or 'STOP' to finish):  Bata
# Enter corresponding Swahili translation:  Bata
# Enter corresponding English translation:  Duck
# Enter Kikuyu word/phrase (or 'STOP' to finish):  Stop
# Enter preferred save format (CSV/JSON):  JSON
# Data saved to translations.json

# %%
import pandas as pd
import json
import os

# Function to collect data
def collect_translation_data():
    data = []
    print("Enter 'STOP' to end data collection.")
    
    while True:
        kikuyu = input("Enter Kikuyu word/phrase (or 'STOP' to finish): ")
        if kikuyu.lower() == 'stop':
            break
        swahili = input("Enter corresponding Swahili translation: ")
        english = input("Enter corresponding English translation: ")
        
        # Append the collected data as a dictionary
        data.append({
            "Kikuyu": kikuyu,
            "Swahili": swahili,
            "English": english
        })
    
    return data

# Function to load existing data from CSV
def load_data_from_csv(filename='translations.csv'):
    if os.path.exists(filename):
        return pd.read_csv(filename).to_dict(orient='records')
    return []

# Function to save data to CSV (with appending functionality)
def save_data_to_csv(data, filename='translations.csv'):
    existing_data = load_data_from_csv(filename)
    combined_data = existing_data + data
    df = pd.DataFrame(combined_data)
    df.to_csv(filename, index=False, encoding='utf-8')
    print(f"Data saved to {filename}")

# Function to load existing data from JSON
def load_data_from_json(filename='translations.json'):
    if os.path.exists(filename):
        with open(filename, 'r', encoding='utf-8') as json_file:
            return json.load(json_file)
    return []

# Function to save data to JSON (with appending functionality)
def save_data_to_json(data, filename='translations.json'):
    existing_data = load_data_from_json(filename)
    combined_data = existing_data + data
    with open(filename, 'w', encoding='utf-8') as json_file:
        json.dump(combined_data, json_file, ensure_ascii=False, indent=4)
    print(f"Data saved to {filename}")

# Main program execution
if __name__ == "__main__":
    collected_data = collect_translation_data()
    if collected_data:
        save_format = input("Enter preferred save format (CSV/JSON): ").lower()
        if save_format == 'csv':
            save_data_to_csv(collected_data)
        elif save_format == 'json':
            save_data_to_json(collected_data)
        else:
            print("Invalid format. Data will not be saved.")
    else:
        print("No data collected.")
# Out:
# Enter 'STOP' to end data collection.
# Enter Kikuyu word/phrase (or 'STOP' to finish):  Mami / Maitũ
# Enter corresponding Swahili translation:  Mama
# Enter corresponding English translation:  Mother
# Enter Kikuyu word/phrase (or 'STOP' to finish):  mũriũ
# Enter corresponding Swahili translation:  Mwana
# Enter corresponding English translation:  Son
# Enter Kikuyu word/phrase (or 'STOP' to finish):  mwarĩ
# Enter corresponding Swahili translation:  Binti
# Enter corresponding English translation:  Daughter
# Enter Kikuyu word/phrase (or 'STOP' to finish):  mwarĩ wa nyina
# Enter corresponding Swahili translation:  dada
# Enter corresponding English translation:  sister
# Enter Kikuyu word/phrase (or 'STOP' to finish):  guka
# Enter corresponding Swahili translation:  Babu
# Enter corresponding English translation:  Grandfather
# Enter Kikuyu word/phrase (or 'STOP' to finish):  cũcũ
# Enter corresponding Swahili translation:  Nyanya
# Enter corresponding English translation:  GrandMother
# Enter Kikuyu word/phrase (or 'STOP' to finish):  mama
# Enter corresponding Swahili translation:  Mjomba
# Enter corresponding English translation:  Uncle
# Enter Kikuyu word/phrase (or 'STOP' to finish):  tata
# Enter corresponding Swahili translation:  shangazi
# Enter corresponding English translation:  Aunt
# Enter Kikuyu word/phrase (or 'STOP' to finish):  mũrũ wa tata
# Enter corresponding Swahili translation:  Binamu
# Enter corresponding English translation:  Male Cousin
# Enter Kikuyu word/phrase (or 'STOP' to finish):  mwarĩ wa tata
# Enter corresponding Swahili translation:  binamu wa kike
# Enter corresponding English translation:  female cousin
# Enter Kikuyu word/phrase (or 'STOP' to finish):  mũihwa
# Enter corresponding Swahili translation:  mpwa
# Enter corresponding English translation:  nephew
# Enter Kikuyu word/phrase (or 'STOP' to finish):  mũihwa
# Enter corresponding Swahili translation:  mpwa wa kiume
# Enter corresponding English translation:  nephew
# Enter Kikuyu word/phrase (or 'STOP' to finish):  mũihwa
# Enter corresponding Swahili translation:  mpwa wa kike
# Enter corresponding English translation:  niece
# Enter Kikuyu word/phrase (or 'STOP' to finish):  mũihwa
# Enter corresponding Swahili translation:  mpwa
# Enter corresponding English translation:  niece
# Enter Kikuyu word/phrase (or 'STOP' to finish):  STOP
# Enter preferred save format (CSV/JSON):  JSON
# Data saved to translations.json

# %%
import pandas as pd
import json
import os

# Function to collect data
def collect_translation_data():
    data = []
    print("Enter 'STOP' to end data collection.")
    
    while True:
        kikuyu = input("Enter Kikuyu word/phrase (or 'STOP' to finish): ")
        if kikuyu.lower() == 'stop':
            break
        swahili = input("Enter corresponding Swahili translation: ")
        english = input("Enter corresponding English translation: ")
        
        # Append the collected data as a dictionary
        data.append({
            "Kikuyu": kikuyu,
            "Swahili": swahili,
            "English": english
        })
    
    return data

# Function to load existing data from CSV
def load_data_from_csv(filename='translations.csv'):
    if os.path.exists(filename):
        return pd.read_csv(filename).to_dict(orient='records')
    return []

# Function to save data to CSV (with appending functionality)
def save_data_to_csv(data, filename='translations.csv'):
    existing_data = load_data_from_csv(filename)
    combined_data = existing_data + data
    df = pd.DataFrame(combined_data)
    df.to_csv(filename, index=False, encoding='utf-8')
    print(f"Data saved to {filename}")

# Function to load existing data from JSON
def load_data_from_json(filename='translations.json'):
    if os.path.exists(filename):
        with open(filename, 'r', encoding='utf-8') as json_file:
            return json.load(json_file)
    return []

# Function to save data to JSON (with appending functionality)
def save_data_to_json(data, filename='translations.json'):
    existing_data = load_data_from_json(filename)
    combined_data = existing_data + data
    with open(filename, 'w', encoding='utf-8') as json_file:
        json.dump(combined_data, json_file, ensure_ascii=False, indent=4)
    print(f"Data saved to {filename}")

# Main program execution
if __name__ == "__main__":
    collected_data = collect_translation_data()
    if collected_data:
        save_format = input("Enter preferred save format (CSV/JSON): ").lower()
        if save_format == 'csv':
            save_data_to_csv(collected_data)
        elif save_format == 'json':
            save_data_to_json(collected_data)
        else:
            print("Invalid format. Data will not be saved.")
    else:
        print("No data collected.")
# Out:
# Enter 'STOP' to end data collection.
# Enter Kikuyu word/phrase (or 'STOP' to finish):  kĩbũgũ
# Enter corresponding Swahili translation:  sufuri
# Enter corresponding English translation:  zero
# Enter Kikuyu word/phrase (or 'STOP' to finish):  ĩmwe
# Enter corresponding Swahili translation:  moja
# Enter corresponding English translation:  one
# Enter Kikuyu word/phrase (or 'STOP' to finish):  igĩrĩ
# Enter corresponding Swahili translation:  mbili
# Enter corresponding English translation:  two
# Enter Kikuyu word/phrase (or 'STOP' to finish):  ithatũ
# Enter corresponding Swahili translation:  tatu
# Enter corresponding English translation:  three
# Enter Kikuyu word/phrase (or 'STOP' to finish):  inya
# Enter corresponding Swahili translation:  nne
# Enter corresponding English translation:  four
# Enter Kikuyu word/phrase (or 'STOP' to finish):  ithano
# Enter corresponding Swahili translation:  tano
# Enter corresponding English translation:  five
# Enter Kikuyu word/phrase (or 'STOP' to finish):  ithathatũ
# Enter corresponding Swahili translation:  sita
# Enter corresponding English translation:  six
# Enter Kikuyu word/phrase (or 'STOP' to finish):  mũgwanja
# Enter corresponding Swahili translation:  saba
# Enter corresponding English translation:  seven
# Enter Kikuyu word/phrase (or 'STOP' to finish):  inyanya
# Enter corresponding Swahili translation:  nane
# Enter corresponding English translation:  eight
# Enter Kikuyu word/phrase (or 'STOP' to finish):  kenda
# Enter corresponding Swahili translation:  tisa
# Enter corresponding English translation:  nine
# Enter Kikuyu word/phrase (or 'STOP' to finish):  ikũmi
# Enter corresponding Swahili translation:  kumi
# Enter corresponding English translation:  ten
# Enter Kikuyu word/phrase (or 'STOP' to finish):  iria
# Enter corresponding Swahili translation:  maziwa
# Enter corresponding English translation:  milk
# Enter Kikuyu word/phrase (or 'STOP' to finish):  nyama
# Enter corresponding Swahili translation:  nyama
# Enter corresponding English translation:  meat
# Enter Kikuyu word/phrase (or 'STOP' to finish):  mboco
# Enter corresponding Swahili translation:  maharagwe
# Enter corresponding English translation:  beans
# Enter Kikuyu word/phrase (or 'STOP' to finish):  mbembe
# Enter corresponding Swahili translation:  ndengũ
# Enter corresponding English translation:  ndengu
# Enter Kikuyu word/phrase (or 'STOP' to finish):  ndengũ
# Enter corresponding Swahili translation:  ndengu
# Enter corresponding English translation:  Greengrams
# Enter Kikuyu word/phrase (or 'STOP' to finish):  ngima
